# %%
# establishing the connection between the sql and jupiter notebook

# %%
# !pip install mysql-connector-python

# %%
# importing the all necessary libaries

# %%
import mysql.connector
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
#Creating connection to the table in mysql

# %%
import pandas as pd
con=mysql.connector.connect(
    host='localhost',
    port=3306,
    user='root',
    password ='DishAnk1013',
    database='disha'
)

# %%
#Reading the table from mysql
#Looking at the data using head,tail,dtype,describe,shape functions

# %%
df=pd.read_sql_query('select * from studmarks2',con)
df
df.head(10)
# Out:
#        Name Gender         DOB  Math  Physics  Chemistry  English  Biology  \
# 0      John      M  05-04-1988    55       45         56       87       21
# 1    Suresh      M  04-05-1987    75       96         78       64       90
# 2    Ramesh      M  25-05-1989    25       54         89       76       95
# 3   Jessica      F  12-08-1990    78       96         86       63       54
# 4  Jennifer      F  02-09-1989    58       96         78       46       96
# 5      Annu      F  05-04-1988    45       87         52       89       55
# 6     pooja      F  04-05-1987    55       64         61       58       75
# 7    Ritesh      M  25-05-1989    54       76         87       56       25
# 8     Farha      F  12-08-1990    55       63         89       75       78
# 9    Mukesh      M  02-09-1989    96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# ...

# %%
df.tail(5)
# Out:
#      Name Gender         DOB  Math  Physics  Chemistry  English  Biology  \
# 5    Annu      F  05-04-1988    45       87         52       89       55
# 6   pooja      F  04-05-1987    55       64         61       58       75
# 7  Ritesh      M  25-05-1989    54       76         87       56       25
# 8   Farha      F  12-08-1990    55       63         89       75       78
# 9  Mukesh      M  02-09-1989    96       46         77       83       58
#
#    Economics  History  Civics
# 5         89       87      52
# 6         58       64      61
# 7         56       76      87
# 8         75       63      89
# 9         83       46      77

# %%
df.dtypes
# Out:
# Name         object
# Gender       object
# DOB          object
# Math          int64
# Physics       int64
# Chemistry     int64
# English       int64
# Biology       int64
# Economics     int64
# History       int64
# Civics        int64
# dtype: object

# %%
df.shape
# Out:
# (10, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 11 columns):
# Name         10 non-null object
# Gender       10 non-null object
# DOB          10 non-null object
# Math         10 non-null int64
# Physics      10 non-null int64
# Chemistry    10 non-null int64
# English      10 non-null int64
# Biology      10 non-null int64
# Economics    10 non-null int64
# History      10 non-null int64
# Civics       10 non-null int64
# dtypes: int64(8), object(3)
# memory usage: 1008.0+ bytes

# %%
df.describe()
# Out:
#             Math    Physics  Chemistry    English    Biology  Economics  \
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean   59.600000  72.300000  75.300000  69.700000  64.700000  72.700000
# std    19.460501  20.661559  14.000397  14.453373  26.998148  14.629119
# min    25.000000  45.000000  52.000000  46.000000  21.000000  52.000000
# 25%    54.250000  56.250000  65.000000  59.250000  54.250000  58.750000
# 50%    55.000000  70.000000  78.000000  69.500000  66.500000  76.000000
# 75%    70.750000  93.750000  86.750000  81.250000  87.000000  86.000000
# max    96.000000  96.000000  89.000000  89.000000  96.000000  89.000000
#
#          History   Civics
# count  10.000000  10.0000
# mean   69.700000  60.5000
# std    14.453373  25.3432
# min    46.000000   2.0000
# 25%    59.250000  52.2500
# 50%    69.500000  63.0000
# 75%    81.250000  76.2500
# max    89.000000  89.0000

# %%
df.isnull().sum() #there are no null values
# Out:
# Name         0
# Gender       0
# DOB          0
# Math         0
# Physics      0
# Chemistry    0
# English      0
# Biology      0
# Economics    0
# History      0
# Civics       0
# dtype: int64

# %% [markdown]
# # univariate analysis

# %%
male=df[df['Gender']=='M']
female = df[df['Gender']=='F']

# %%
male.describe()
# Out:
#             Math    Physics  Chemistry    English    Biology  Economics  \
# count   5.000000   5.000000   5.000000   5.000000   5.000000   5.000000
# mean   61.000000  63.400000  77.400000  73.200000  57.800000  67.800000
# std    26.466961  22.086195  13.088163  12.988456  34.823842  16.084154
# min    25.000000  45.000000  56.000000  56.000000  21.000000  52.000000
# 25%    54.000000  46.000000  77.000000  64.000000  25.000000  56.000000
# 50%    55.000000  54.000000  78.000000  76.000000  58.000000  61.000000
# 75%    75.000000  76.000000  87.000000  83.000000  90.000000  83.000000
# max    96.000000  96.000000  89.000000  87.000000  95.000000  87.000000
#
#          History     Civics
# count   5.000000   5.000000
# mean   65.000000  61.000000
# std    17.233688  33.904277
# min    46.000000   2.000000
# 25%    56.000000  65.000000
# 50%    58.000000  74.000000
# 75%    76.000000  77.000000
# max    89.000000  87.000000

# %%
female.describe()
# Out:
#             Math    Physics  Chemistry    English    Biology  Economics  \
# count   5.000000   5.000000   5.000000   5.000000   5.000000    5.00000
# mean   58.200000  81.200000  73.200000  66.200000  71.600000   77.60000
# std    12.111978  16.574076  16.084154  16.452963  17.558474   12.75931
# min    45.000000  63.000000  52.000000  46.000000  54.000000   58.00000
# 25%    55.000000  64.000000  61.000000  58.000000  55.000000   75.00000
# 50%    55.000000  87.000000  78.000000  63.000000  75.000000   77.00000
# 75%    58.000000  96.000000  86.000000  75.000000  78.000000   89.00000
# max    78.000000  96.000000  89.000000  89.000000  96.000000   89.00000
#
#          History     Civics
# count   5.000000   5.000000
# mean   74.400000  60.000000
# std    10.853571  17.175564
# min    63.000000  45.000000
# 25%    64.000000  52.000000
# 50%    75.000000  53.000000
# 75%    83.000000  61.000000
# max    87.000000  89.000000

# %%
data=df[['Math','Physics','Chemistry','English','Biology','Economics','History','Civics']]
fig,ax = plt.subplots(figsize = (15,5))
plt.boxplot(data.values,labels =['Math','Physics','Chemistry','English','Biology','Economics','History','Civics'] );

# %% [markdown]
# # bivariate analysis

# %%
df.corr()
# Out:
#                Math   Physics  Chemistry   English   Biology  Economics  \
# Math       1.000000  0.113354   0.076751 -0.064074 -0.146598   0.000312
# Physics    0.113354  1.000000   0.117192 -0.562608  0.279638   0.191851
# Chemistry  0.076751  0.117192   1.000000 -0.409680  0.318032   0.235390
# English   -0.064074 -0.562608  -0.409680  1.000000 -0.330844   0.237577
# Biology   -0.146598  0.279638   0.318032 -0.330844  1.000000   0.370531
# Economics  0.000312  0.191851   0.235390  0.237577  0.370531   1.000000
# History   -0.320846  0.334082  -0.482710 -0.038775 -0.456131  -0.164953
# Civics    -0.274629 -0.643266   0.210908  0.186705 -0.330060   0.043905
#
#             History    Civics
# Math      -0.320846 -0.274629
# Physics    0.334082 -0.643266
# Chemistry -0.482710  0.210908
# English   -0.038775  0.186705
# Biology   -0.456131 -0.330060
# Economics -0.164953  0.043905
# History    1.000000 -0.048686
# Civics    -0.048686  1.000000

# %%
#have obtained data from my sql file
#there are no missing values or outliers in the data
#all the students have date of birth in 1987 and 1988
#In boxplot for maths and civics shows two values which we think is outlier but actually its not because students can obtain 100 or 0 marks
#highest negative correlation is seen between marks of physics and civics so we can say that if one student score good marks in physics he is not scoring well in civics and vice versa
#English and Phusics are also negatively correlated
#Female perform better than males in Physics, Biology, Economics and History based on mean score
#Male performed better than females in math and chemistry
#Male and female performed equally in Civics
